# %% [markdown]
# <a href="https://colab.research.google.com/github/febinchundakkattiil/numpy/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = {
    "Name": ["Alice", "Bob", "Charlie", "Alice", "Eva", "Frank", "Grace", "Hannah", "Alice", "Julia"],
    "Age": [24, 30, 22, 24, 26, None, 21, None, 33, 27],
    "City": ["Mumbai", "Delhi", "Chennai", "Mumbai", "Bengaluru", "Hyderabad", "Pune", "Ahmedabad", "Jaipur", "Lucknow"],
    "Sal" : [200,300,None,200,None,3421,789,213,None,1000]
    }

# %%
data = pd.DataFrame(data)
data
# Out:
#       Name   Age       City     Sal
# 0    Alice  24.0     Mumbai   200.0
# 1      Bob  30.0      Delhi   300.0
# 2  Charlie  22.0    Chennai     NaN
# 3    Alice  24.0     Mumbai   200.0
# 4      Eva  26.0  Bengaluru     NaN
# 5    Frank   NaN  Hyderabad  3421.0
# 6    Grace  21.0       Pune   789.0
# 7   Hannah   NaN  Ahmedabad   213.0
# 8    Alice  33.0     Jaipur     NaN
# 9    Julia  27.0    Lucknow  1000.0

# %%
data.head(3)
# Out:
#       Name   Age     City    Sal
# 0    Alice  24.0   Mumbai  200.0
# 1      Bob  30.0    Delhi  300.0
# 2  Charlie  22.0  Chennai    NaN

# %%
data.tail(2)
# Out:
#     Name   Age     City     Sal
# 8  Alice  33.0   Jaipur     NaN
# 9  Julia  27.0  Lucknow  1000.0

# %%
df = data
df
# Out:
#       Name   Age       City     Sal
# 0    Alice  24.0     Mumbai   200.0
# 1      Bob  30.0      Delhi   300.0
# 2  Charlie  22.0    Chennai     NaN
# 3    Alice  24.0     Mumbai   200.0
# 4      Eva  26.0  Bengaluru     NaN
# 5    Frank   NaN  Hyderabad  3421.0
# 6    Grace  21.0       Pune   789.0
# 7   Hannah   NaN  Ahmedabad   213.0
# 8    Alice  33.0     Jaipur     NaN
# 9    Julia  27.0    Lucknow  1000.0

# %%
df[['Sal','Age',"City"]]
# Out:
#       Sal   Age       City
# 0   200.0  24.0     Mumbai
# 1   300.0  30.0      Delhi
# 2     NaN  22.0    Chennai
# 3   200.0  24.0     Mumbai
# 4     NaN  26.0  Bengaluru
# 5  3421.0   NaN  Hyderabad
# 6   789.0  21.0       Pune
# 7   213.0   NaN  Ahmedabad
# 8     NaN  33.0     Jaipur
# 9  1000.0  27.0    Lucknow

# %%
df.drop('Sal',axis=1)
# Out:
#       Name   Age       City
# 0    Alice  24.0     Mumbai
# 1      Bob  30.0      Delhi
# 2  Charlie  22.0    Chennai
# 3    Alice  24.0     Mumbai
# 4      Eva  26.0  Bengaluru
# 5    Frank   NaN  Hyderabad
# 6    Grace  21.0       Pune
# 7   Hannah   NaN  Ahmedabad
# 8    Alice  33.0     Jaipur
# 9    Julia  27.0    Lucknow

# %%
df
# Out:
#       Name   Age       City     Sal
# 0    Alice  24.0     Mumbai   200.0
# 1      Bob  30.0      Delhi   300.0
# 2  Charlie  22.0    Chennai     NaN
# 3    Alice  24.0     Mumbai   200.0
# 4      Eva  26.0  Bengaluru     NaN
# 5    Frank   NaN  Hyderabad  3421.0
# 6    Grace  21.0       Pune   789.0
# 7   Hannah   NaN  Ahmedabad   213.0
# 8    Alice  33.0     Jaipur     NaN
# 9    Julia  27.0    Lucknow  1000.0

# %%
df.shape
# Out:
# (10, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    10 non-null     object
#  1   Age     8 non-null      float64
#  2   City    10 non-null     object
#  3   Sal     7 non-null      float64
# dtypes: float64(2), object(2)
# memory usage: 452.0+ bytes

# %%
df.describe()
# Out:
#              Age          Sal
# count   8.000000     7.000000
# mean   25.875000   874.714286
# std     4.051014  1167.993681
# min    21.000000   200.000000
# 25%    23.500000   206.500000
# 50%    25.000000   300.000000
# 75%    27.750000   894.500000
# max    33.000000  3421.000000

# %%
df
# Out:
#       Name   Age       City     Sal
# 0    Alice  24.0     Mumbai   200.0
# 1      Bob  30.0      Delhi   300.0
# 2  Charlie  22.0    Chennai     NaN
# 3    Alice  24.0     Mumbai   200.0
# 4      Eva  26.0  Bengaluru     NaN
# 5    Frank   NaN  Hyderabad  3421.0
# 6    Grace  21.0       Pune   789.0
# 7   Hannah   NaN  Ahmedabad   213.0
# 8    Alice  33.0     Jaipur     NaN
# 9    Julia  27.0    Lucknow  1000.0

# %%
df["Sal"] = df["Sal"] + 200
df
# Out:
#       Name   Age       City     Sal
# 0    Alice  24.0     Mumbai   400.0
# 1      Bob  30.0      Delhi   500.0
# 2  Charlie  22.0    Chennai     NaN
# 3    Alice  24.0     Mumbai   400.0
# 4      Eva  26.0  Bengaluru     NaN
# 5    Frank   NaN  Hyderabad  3621.0
# 6    Grace  21.0       Pune   989.0
# 7   Hannah   NaN  Ahmedabad   413.0
# 8    Alice  33.0     Jaipur     NaN
# 9    Julia  27.0    Lucknow  1200.0

# %%
df.rename(columns = {'City':'cities'},inplace = True)

# %%
df
# Out:
#       Name   Age     cities     Sal
# 0    Alice  24.0     Mumbai   400.0
# 1      Bob  30.0      Delhi   500.0
# 2  Charlie  22.0    Chennai     NaN
# 3    Alice  24.0     Mumbai   400.0
# 4      Eva  26.0  Bengaluru     NaN
# 5    Frank   NaN  Hyderabad  3621.0
# 6    Grace  21.0       Pune   989.0
# 7   Hannah   NaN  Ahmedabad   413.0
# 8    Alice  33.0     Jaipur     NaN
# 9    Julia  27.0    Lucknow  1200.0

# %%
df["Sal"].unique()
# Out:
# array([ 400.,  500.,   nan, 3621.,  989.,  413., 1200.])

# %%
df["cities"].value_counts()
# Out:
# cities
# Mumbai       2
# Delhi        1
# Chennai      1
# Bengaluru    1
# Hyderabad    1
# Pune         1
# Ahmedabad    1
# Jaipur       1
# Lucknow      1
# Name: count, dtype: int64

# %%
df["Promoted Sal"] = df['Sal'] * 5

# %%
df
# Out:
#       Name   Age     cities     Sal  Promoted Sal
# 0    Alice  24.0     Mumbai   400.0        2000.0
# 1      Bob  30.0      Delhi   500.0        2500.0
# 2  Charlie  22.0    Chennai     NaN           NaN
# 3    Alice  24.0     Mumbai   400.0        2000.0
# 4      Eva  26.0  Bengaluru     NaN           NaN
# 5    Frank   NaN  Hyderabad  3621.0       18105.0
# 6    Grace  21.0       Pune   989.0        4945.0
# 7   Hannah   NaN  Ahmedabad   413.0        2065.0
# 8    Alice  33.0     Jaipur     NaN           NaN
# 9    Julia  27.0    Lucknow  1200.0        6000.0

# %%
df.isnull().sum()
# Out:
# Name            0
# Age             2
# cities          0
# Sal             3
# Promoted Sal    3
# dtype: int64

# %%
df.dropna()
# Out:
#     Name   Age   cities     Sal  Promoted Sal
# 0  Alice  24.0   Mumbai   400.0        2000.0
# 1    Bob  30.0    Delhi   500.0        2500.0
# 3  Alice  24.0   Mumbai   400.0        2000.0
# 6  Grace  21.0     Pune   989.0        4945.0
# 9  Julia  27.0  Lucknow  1200.0        6000.0

# %%
df
# Out:
#       Name   Age     cities     Sal  Promoted Sal
# 0    Alice  24.0     Mumbai   400.0        2000.0
# 1      Bob  30.0      Delhi   500.0        2500.0
# 2  Charlie  22.0    Chennai     NaN           NaN
# 3    Alice  24.0     Mumbai   400.0        2000.0
# 4      Eva  26.0  Bengaluru     NaN           NaN
# 5    Frank   NaN  Hyderabad  3621.0       18105.0
# 6    Grace  21.0       Pune   989.0        4945.0
# 7   Hannah   NaN  Ahmedabad   413.0        2065.0
# 8    Alice  33.0     Jaipur     NaN           NaN
# 9    Julia  27.0    Lucknow  1200.0        6000.0

# %%
df.dropna(how = 'any')
# Out:
#     Name   Age   cities     Sal  Promoted Sal
# 0  Alice  24.0   Mumbai   400.0        2000.0
# 1    Bob  30.0    Delhi   500.0        2500.0
# 3  Alice  24.0   Mumbai   400.0        2000.0
# 6  Grace  21.0     Pune   989.0        4945.0
# 9  Julia  27.0  Lucknow  1200.0        6000.0

# %%
df["Age"].fillna(df["Age"].mean())
# Out:
# 0    24.000
# 1    30.000
# 2    22.000
# 3    24.000
# 4    26.000
# 5    25.875
# 6    21.000
# 7    25.875
# 8    33.000
# 9    27.000
# Name: Age, dtype: float64

# %%
df
# Out:
#       Name   Age     cities     Sal  Promoted Sal
# 0    Alice  24.0     Mumbai   400.0        2000.0
# 1      Bob  30.0      Delhi   500.0        2500.0
# 2  Charlie  22.0    Chennai     NaN           NaN
# 3    Alice  24.0     Mumbai   400.0        2000.0
# 4      Eva  26.0  Bengaluru     NaN           NaN
# 5    Frank   NaN  Hyderabad  3621.0       18105.0
# 6    Grace  21.0       Pune   989.0        4945.0
# 7   Hannah   NaN  Ahmedabad   413.0        2065.0
# 8    Alice  33.0     Jaipur     NaN           NaN
# 9    Julia  27.0    Lucknow  1200.0        6000.0

# %%
df["Sal"].fillna(df["Sal"].median())
# Out:
# 0     400.0
# 1     500.0
# 2     500.0
# 3     400.0
# 4     500.0
# 5    3621.0
# 6     989.0
# 7     413.0
# 8     500.0
# 9    1200.0
# Name: Sal, dtype: float64

# %%
df["Age"].fillna(method = "ffill")
# Out:
# /tmp/ipython-input-301-544980945.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["Age"].fillna(method = "ffill")
# 0    24.0
# 1    30.0
# 2    22.0
# 3    24.0
# 4    26.0
# 5    26.0
# 6    21.0
# 7    21.0
# 8    33.0
# 9    27.0
# Name: Age, dtype: float64

# %%
df["Age"].fillna(method = "bfill")
# Out:
# /tmp/ipython-input-302-3026805218.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["Age"].fillna(method = "bfill")
# 0    24.0
# 1    30.0
# 2    22.0
# 3    24.0
# 4    26.0
# 5    21.0
# 6    21.0
# 7    33.0
# 8    33.0
# 9    27.0
# Name: Age, dtype: float64

# %%
df["Name"].replace("Charlie","Rose")
# Out:
# 0     Alice
# 1       Bob
# 2      Rose
# 3     Alice
# 4       Eva
# 5     Frank
# 6     Grace
# 7    Hannah
# 8     Alice
# 9     Julia
# Name: Name, dtype: object

# %%
df["Name"] = df["Name"].replace("Charlie", "Rose")
df
# Out:
#      Name   Age     cities     Sal  Promoted Sal
# 0   Alice  24.0     Mumbai   400.0        2000.0
# 1     Bob  30.0      Delhi   500.0        2500.0
# 2    Rose  22.0    Chennai     NaN           NaN
# 3   Alice  24.0     Mumbai   400.0        2000.0
# 4     Eva  26.0  Bengaluru     NaN           NaN
# 5   Frank   NaN  Hyderabad  3621.0       18105.0
# 6   Grace  21.0       Pune   989.0        4945.0
# 7  Hannah   NaN  Ahmedabad   413.0        2065.0
# 8   Alice  33.0     Jaipur     NaN           NaN
# 9   Julia  27.0    Lucknow  1200.0        6000.0

# %%
df =df[df.duplicated()]
df
# Out:
#     Name   Age  cities    Sal  Promoted Sal
# 3  Alice  24.0  Mumbai  400.0        2000.0
